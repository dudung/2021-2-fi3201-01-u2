# %% [markdown]
# # draw_shapes
# Jalankan kode pada sel-sel di bawah ini sehingga identitas Anda tertampilkan dengan benar dan gambarkan beberapa bentuk.

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")

import sys, os
sys.path.insert(1, os.path.join(sys.path[0], '../..'))

from src.student import Students as stu
nim = 10218009
print(nim, end=' ')
print(stu[nim]['name'], end=' ')
print("https://github.com/", stu[nim]['github'], sep='')
# Out:
# 10218009 Akram Akbar Amin https://github.com/AkramAkbarAmin

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## circle
# Sebuah lingkaran dengan pusat `(xc, yc)`, radius `r`, berisi warna `#ccf`, garis batas berwarna `k`, tebal garis `2`, dan jenis garis `dashed` digambarkan dengan kode berikut ini.

# %%
xc = 1
yc = 0
r = 0.5
circle = plt.Circle(
    (xc, yc), radius=r,
    fc='#ccf',
    lw=2, ls='dashed', color='k'
)
plt.gca().add_patch(circle)
plt.axis('scaled')
plt.show()

# %% [markdown]
# ## rectangle
# Sebuah persegi panjang dengan titik sudut `(x, y)`, lebar `w`, tinggi `h`, berisi warna `y`, garis batas bewarna `r`, jenis garis `dotted`, tebal garis `3` dapat digambarkan dengan kode berikut ini.

# %%
x = 20
y = 20
w = 80
h = 90
rectangle = plt.Rectangle(
    (x, y), w, h,
    fc='y',
    color='r', ls='dotted', lw=3
)
plt.gca().add_patch(rectangle)
plt.axis('scaled')
plt.show()

# %% [markdown]
# ## line
# Sebuah garis lurus yang menghubungkan titik `(x1, y1)` dan `(x2, y2)` dengan warna garis `#aca`, tebal `1`, dan jenis garis `solid` dapat diperoleh menggunakan kode berikut ini.

# %%
x1 = 10
y1 = 20
x2 = 50
y2 = 60
line = plt.Line2D((x1, x2), (y1, y2), color='#4c4', lw=1, ls='solid')
plt.gca().add_line(line)
plt.axis('scaled')
plt.show()

# %% [markdown]
# ## shapes
# Untuk mendapatkan gambar di bawah ini
#
# ![](draw_3_shapes.png)
#
# lengkapi kode berikut.

# %%
import math

# ..
#circle = plt.Circle( .. )
#plt.gca().add_patch(circle)

# ..
#rectangle = plt.Rectangle( .. )
#plt.gca().add_patch(rectangle)

# ..
#line = plt.Line2D( .. )
#plt.gca().add_line(line)

plt.axis('scaled')
plt.show()

# %% [markdown]
# # Jawaban
# Untuk mendapatkan gambar shapes seperti diatas, perlu dilengkapi kode pada sel diatas dengan menggabungkan kode circle, rectangle, dan line. Selanjutnya, edit ukuran dan warna yang sesuai sehingga mendapatkan gambar yang diharapkan. Kode dan output yang diperoleh sebagai berikut:

# %%
import math

# Circle
xc = 20
yc = 20
r = 10
circle = plt.Circle(
    (xc, yc), radius=r,
    fc='#ccf',
    lw=2, ls='dashed', color='k')
plt.gca().add_patch(circle)

# Rectangle
x = 80
y = 80
w = 20
h = 20
rectangle = plt.Rectangle(
    (x, y), w, h,
    fc='blue',
    color='r', ls='solid', lw=3
)
plt.gca().add_patch(rectangle)

# Line
x1 = 27.5
y1 = 27.5
x2 = 80
y2 = 80
line = plt.Line2D((x1, x2), (y1, y2), color='#4c4', lw=2, ls='solid')
plt.gca().add_line(line)

plt.axis('scaled')
plt.show()
